# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 import pandas as pd
#
# File ~/miniforge3/envs/dfenv/lib/python3.8/site-packages/pandas/__init__.py:179, in <module>
#     176 from pandas.io.json import _json_normalize as json_normalize
#     178 from pandas.util._tester import test
# --> 179 import pandas.testing
#     180 import pandas.arrays
#     182 # use the closest tagged version if possible
#
# File ~/miniforge3/envs/dfenv/lib/python3.8/site-packages/pandas/testing.py:6, in <module>
#       1 """
#       2 Public testing utility functions.
#       3 """
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#       9     assert_index_equal,
#      10     assert_series_equal,
#      11 )
#      13 __all__ = [
#      14     "assert_extension_array_equal",
# ...
